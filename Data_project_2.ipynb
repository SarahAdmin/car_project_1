# %% [markdown]
# <a href="https://colab.research.google.com/github/SarahAdmin/car_project_1/blob/main/Data_project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def myCar(model,colour):
  print('My car is '+model+' and my colour of my car is '+colour)

myCar('Yaris','Black')
myCar('Fiesta','Lime')
# Out:
# My car is Yaris and my colour of my car is Black
# My car is Fiesta and my colour of my car is Lime

# %%
import pandas as pd
testDF = pd.read_csv('theory_test_data.csv',encoding='latin-1')

# %%
testDF
# Out:
#                  Name  Score_out_of_50 Status     Vehicle
# 0             Lee Cox               44   Pass         Car
# 1           Matt Bond               43   Pass         Car
# 2         Lemon Jelly               33   Fail         Car
# 3      Maragret Adams               40   Fail         Car
# 4          Geri Green               47   Pass  Motorcycle
# 5            Jo Quinn               20   Fail  Motorcycle
# 6          Gill Gates               50   Pass         Car
# 7        Lisa Barnes                45   Pass         Car
# 8     Pamela Hathaway               48   Pass         Car
# 9         Jade Wright               43   Pass         Car
# 10       Zoe Saunders               41   Fail        Car
# 11         Judy Scott               46   Pass         Car
# 12         Sarah King               41   Fail  Motorcycle
# 13      Joshua Bunton               44   Pass         Car
# 14    Danielle Knight               45   Pass  Motorcycle
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
testDF.groupby('Status').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
testDF.where((testDF['Status'] == 'Pass') & (testDF['Vehicle'] == 'Car')).dropna()
# Out:
#                Name  Score_out_of_50 Status Vehicle
# 0           Lee Cox             44.0   Pass     Car
# 1         Matt Bond             43.0   Pass     Car
# 6        Gill Gates             50.0   Pass     Car
# 7      Lisa Barnes              45.0   Pass     Car
# 8   Pamela Hathaway             48.0   Pass     Car
# 9       Jade Wright             43.0   Pass     Car
# 11       Judy Scott             46.0   Pass     Car
# 13    Joshua Bunton             44.0   Pass     Car
# 15       Paige Ryan             43.0   Pass     Car

# %%
testDF.where((testDF['Status'] == 'Fail')).dropna()
# Out:
#                  Name  Score_out_of_50 Status     Vehicle
# 2         Lemon Jelly             33.0   Fail         Car
# 3      Maragret Adams             40.0   Fail         Car
# 5            Jo Quinn             20.0   Fail  Motorcycle
# 10       Zoe Saunders             41.0   Fail        Car
# 12         Sarah King             41.0   Fail  Motorcycle
# 16  Richard Blackburn             42.0   Fail         Car

# %%
testDF.where((testDF['Status'] == 'Pass')).dropna()
# Out:
#                Name  Score_out_of_50 Status     Vehicle
# 0           Lee Cox             44.0   Pass         Car
# 1         Matt Bond             43.0   Pass         Car
# 4        Geri Green             47.0   Pass  Motorcycle
# 6        Gill Gates             50.0   Pass         Car
# 7      Lisa Barnes              45.0   Pass         Car
# 8   Pamela Hathaway             48.0   Pass         Car
# 9       Jade Wright             43.0   Pass         Car
# 11       Judy Scott             46.0   Pass         Car
# 13    Joshua Bunton             44.0   Pass         Car
# 14  Danielle Knight             45.0   Pass  Motorcycle
# 15       Paige Ryan             43.0   Pass         Car
# 17     Yasmin Jones             43.0   Pass        Car

# %%
import pandas as pd
testDF = pd.read_csv('theory_test_data.csv',encoding='latin-1')

# %%
testDF.where(testDF['Score_out_of_50'] < 43).dropna()
# Out:
#                  Name  Score_out_of_50 Status     Vehicle
# 2         Lemon Jelly             33.0   Fail         Car
# 3      Maragret Adams             40.0   Fail         Car
# 5            Jo Quinn             20.0   Fail  Motorcycle
# 10       Zoe Saunders             41.0   Fail        Car
# 12         Sarah King             41.0   Fail  Motorcycle
# 16  Richard Blackburn             42.0   Fail         Car

# %%
testDF.where(testDF['Score_out_of_50'] >= 43).dropna()
# Out:
#                Name  Score_out_of_50 Status     Vehicle
# 0           Lee Cox             44.0   Pass         Car
# 1         Matt Bond             43.0   Pass         Car
# 4        Geri Green             47.0   Pass  Motorcycle
# 6        Gill Gates             50.0   Pass         Car
# 7      Lisa Barnes              45.0   Pass         Car
# 8   Pamela Hathaway             48.0   Pass         Car
# 9       Jade Wright             43.0   Pass         Car
# 11       Judy Scott             46.0   Pass         Car
# 13    Joshua Bunton             44.0   Pass         Car
# 14  Danielle Knight             45.0   Pass  Motorcycle
# 15       Paige Ryan             43.0   Pass         Car
# 17     Yasmin Jones             43.0   Pass        Car
