# %% [markdown]
# <a href="https://colab.research.google.com/github/SarahAdmin/car_project_1/blob/main/Car_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
carDF = pd.read_csv('car_data.csv',encoding='latin-1')
columnToDelete = ['No_of_Seats']
carDF = carDF.drop(columnToDelete,axis=1)
print(carDF.to_string())
# Out:
#           Make    Model     Colour  Year Fuel Type Transmission    Price
# 0       Toyota    Yaris        Red  2019  Unleaded       Manual  £22,593
# 1         Ford   Fiesta       Blue  2024  Unleaded       Manual  £27,958
# 2   Volkswagen  T-Cross      Black  2020  Unleaded       Manual  £30,289
# 3       Toyota    Yaris      White  2019  Unleaded       Manual  £21,685
# 4         Ford   Fiesta  Navy Blue  2024    Diesel       Manual  £25,385
# 5       Toyota    Yaris        Red  2019  Unleaded       Manual  £21,485
# 6     Vauxhall    Corsa      White  2024  Unleaded    Automatic  £21,593
# 7   Volkswagen  T-Cross       Grey  2022    Diesel       Manual  £25,689
# 8         Ford     Puma  Navy Blue  2023  Unleaded    Automatic  £24,695
# 9   Volkswagen     Polo      White  2024  Unleaded       Manual  £25,583
# 10        Ford   Fiesta       Blue  2024  Unleaded       Manual  £21,475
# 11      Toyota    Yaris       Grey  2024  Unleaded       Manual  £27,593
# ...

# %%
carDF['Model']
# Out:
# 0       Yaris
# 1      Fiesta
# 2     T-Cross
# 3       Yaris
# 4      Fiesta
# 5       Yaris
# 6       Corsa
# 7     T-Cross
# 8        Puma
# 9        Polo
# 10     Fiesta
# 11      Yaris
# 12    T-Cross
# 13      Rav-4
# 14     Fiesta
# 15      Corsa
# 16      Rav-4
# 17      T-Roc
# 18       C-HR
# 19       Puma
# 20       500e
# 21       500e
# 22     Fiesta
# Name: Model, dtype: object

# %%
carDF.dtypes
# Out:
# Make            object
# Model           object
# Colour          object
# Year             int64
# Fuel Type       object
# Transmission    object
# Price           object
# dtype: object

# %%
carDF.where(carDF['Make'] == 'Ford').dropna()
# Out:
#     Make   Model     Colour    Year Fuel Type Transmission    Price
# 1   Ford  Fiesta       Blue  2024.0  Unleaded       Manual  £27,958
# 4   Ford  Fiesta  Navy Blue  2024.0    Diesel       Manual  £25,385
# 8   Ford    Puma  Navy Blue  2023.0  Unleaded    Automatic  £24,695
# 10  Ford  Fiesta       Blue  2024.0  Unleaded       Manual  £21,475
# 14  Ford  Fiesta       Blue  2024.0  Unleaded       Manual  £32,593
# 19  Ford    Puma       Lime  2025.0  Unleaded       Manual  £20,495
# 22  Ford  Fiesta      White  2025.0  Electric    Automatic  £18,485

# %%
carDF.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# dtype: bool

# %%
carDF.where((carDF['Model'] == 'Yaris') | (carDF['Fuel Type'] == 'Unleaded')).dropna()
# Out:
#           Make    Model     Colour    Year Fuel Type Transmission    Price
# 0       Toyota    Yaris        Red  2019.0  Unleaded       Manual  £22,593
# 1         Ford   Fiesta       Blue  2024.0  Unleaded       Manual  £27,958
# 2   Volkswagen  T-Cross      Black  2020.0  Unleaded       Manual  £30,289
# 3       Toyota    Yaris      White  2019.0  Unleaded       Manual  £21,685
# 5       Toyota    Yaris        Red  2019.0  Unleaded       Manual  £21,485
# 6     Vauxhall    Corsa      White  2024.0  Unleaded    Automatic  £21,593
# 8         Ford     Puma  Navy Blue  2023.0  Unleaded    Automatic  £24,695
# 9   Volkswagen     Polo      White  2024.0  Unleaded       Manual  £25,583
# 10        Ford   Fiesta       Blue  2024.0  Unleaded       Manual  £21,475
# 11      Toyota    Yaris       Grey  2024.0  Unleaded       Manual  £27,593
# 12  Volkswagen  T-Cross      White  2021.0  Unleaded       Manual  £20,482
# ...

# %%
carDF
# Out:
#           Make    Model     Colour  Year Fuel Type Transmission    Price
# 0       Toyota    Yaris        Red  2019  Unleaded       Manual  £22,593
# 1         Ford   Fiesta       Blue  2024  Unleaded       Manual  £27,958
# 2   Volkswagen  T-Cross      Black  2020  Unleaded       Manual  £30,289
# 3       Toyota    Yaris      White  2019  Unleaded       Manual  £21,685
# 4         Ford   Fiesta  Navy Blue  2024    Diesel       Manual  £25,385
# 5       Toyota    Yaris        Red  2019  Unleaded       Manual  £21,485
# 6     Vauxhall    Corsa      White  2024  Unleaded    Automatic  £21,593
# 7   Volkswagen  T-Cross       Grey  2022    Diesel       Manual  £25,689
# 8         Ford     Puma  Navy Blue  2023  Unleaded    Automatic  £24,695
# 9   Volkswagen     Polo      White  2024  Unleaded       Manual  £25,583
# 10        Ford   Fiesta       Blue  2024  Unleaded       Manual  £21,475
# 11      Toyota    Yaris       Grey  2024  Unleaded       Manual  £27,593
# ...

# %%
carDF.where((carDF['Model'] == 'Yaris') & (carDF['Colour'] == 'Red')).dropna()
# Out:
#      Make  Model Colour    Year Fuel Type Transmission    Price
# 0  Toyota  Yaris    Red  2019.0  Unleaded       Manual  £22,593
# 5  Toyota  Yaris    Red  2019.0  Unleaded       Manual  £21,485

# %%
carDF.where((carDF['Make'] == 'Ford') & (carDF['Fuel Type'] == 'Unleaded')).dropna()
# Out:
#     Make   Model     Colour    Year Fuel Type Transmission    Price
# 1   Ford  Fiesta       Blue  2024.0  Unleaded       Manual  £27,958
# 8   Ford    Puma  Navy Blue  2023.0  Unleaded    Automatic  £24,695
# 10  Ford  Fiesta       Blue  2024.0  Unleaded       Manual  £21,475
# 14  Ford  Fiesta       Blue  2024.0  Unleaded       Manual  £32,593
# 19  Ford    Puma       Lime  2025.0  Unleaded       Manual  £20,495

# %%
carDF[['Make','Model']]
# Out:
#           Make    Model
# 0       Toyota    Yaris
# 1         Ford   Fiesta
# 2   Volkswagen  T-Cross
# 3       Toyota    Yaris
# 4         Ford   Fiesta
# 5       Toyota    Yaris
# 6     Vauxhall    Corsa
# 7   Volkswagen  T-Cross
# 8         Ford     Puma
# 9   Volkswagen     Polo
# 10        Ford   Fiesta
# 11      Toyota    Yaris
# 12  Volkswagen  T-Cross
# 13     Toyota     Rav-4
# 14        Ford   Fiesta
# 15    Vauxhall    Corsa
# 16      Toyota    Rav-4
# 17  Volkswagen    T-Roc
# 18      Toyota     C-HR
# 19        Ford     Puma
# 20        Fiat     500e
# 21        Fiat     500e
# 22        Ford   Fiesta
