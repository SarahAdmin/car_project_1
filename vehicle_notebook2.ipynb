# %%
import pandas as pd
df = pd.read_csv('disabled-vehicle-data.csv',encoding='latin-1')
df['Year'] = df['Year'].astype(str)

# %%
df.style.background_gradient(cmap='RdPu')
# Out:
# <style type="text/css">
# #T_297c0_row0_col3 {
#   background-color: #f361a0;
#   color: #f1f1f1;
# }
# #T_297c0_row0_col5 {
#   background-color: #fa9db4;
#   color: #000000;
# }
# #T_297c0_row0_col6 {
#   background-color: #b0037f;
#   color: #f1f1f1;
# }
# #T_297c0_row1_col3, #T_297c0_row1_col6, #T_297c0_row5_col5 {
#   background-color: #fff7f3;
#   color: #000000;
# }
# #T_297c0_row1_col5 {
#   background-color: #fde4e0;
#   color: #000000;
# }
# #T_297c0_row2_col3 {
#   background-color: #5d006f;
#   color: #f1f1f1;
# }
# #T_297c0_row2_col5 {
#   background-color: #d02690;
#   color: #f1f1f1;
# }
# #T_297c0_row2_col6 {
#   background-color: #aa017d;
#   color: #f1f1f1;
# }
# #T_297c0_row3_col3 {
#   background-color: #790177;
#   color: #f1f1f1;
# }
# #T_297c0_row3_col5 {
#   background-color: #730175;
#   color: #f1f1f1;
# }
# #T_297c0_row3_col6 {
#   background-color: #840178;
#   color: #f1f1f1;
# }
# #T_297c0_row4_col3 {
#   background-color: #ee579e;
#   color: #f1f1f1;
# ...
